# %%
from scipy.io import wavfile

# %%
import matplotlib.pylab as plt

# %%
location='/home/sayantan/documents/SDR-Decode/Untitled Folder/audio2.wav'

# %%
rate,data = wavfile.read('./audios.wav','rp')

# %%
rate
# Out:
# 192000

# %%
data
# Out:
# memmap([[ -3, -60],
#         [ -4, -72],
#         [ -3, -75],
#         ...,
#         [ 29, -48],
#         [ 58, -17],
#         [ 82,   5]], dtype=int16)

# %%
len(data)
# Out:
# 9810368

# %%
#change this 100 to 10 ,5 ,4 what ever you want
data=data[::20000]

# %%
len(data)
# Out:
# 491

# %%
import numpy as np

# %%
ind=np.arange(len(data))
plt.plot(ind,data)
